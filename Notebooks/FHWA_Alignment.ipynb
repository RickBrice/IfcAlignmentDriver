# %%
import matplotlib.pyplot as plt
import math
import ifcopenshell
import ifcopenshell.api.alignment
import ifcopenshell.api.unit
import ifcopenshell.geom
import numpy as np

file = ifcopenshell.file(schema="IFC4X3_ADD2")
project = file.createIfcProject(GlobalId=ifcopenshell.guid.new(),Name="FHWA Alignment")
#ifcopenshell.api.unit.assign_unit(file)
#length = ifcopenshell.api.unit.add_si_unit(file,unit_type="LENGTHUNIT")
length = ifcopenshell.api.unit.add_conversion_based_unit(file,name="foot")
ifcopenshell.api.unit.assign_unit(file,units=[length])
geometric_representation_context = ifcopenshell.api.context.add_context(file, context_type="Model")
axis_model_representation_subcontext = ifcopenshell.api.context.add_context(
    file,
    context_type="Model",
    context_identifier="Axis",
    target_view="MODEL_VIEW",
    parent=geometric_representation_context,
)

alignment = ifcopenshell.api.alignment.create(file,"E-Line",include_vertical=True,start_station=10000.)
layout = ifcopenshell.api.alignment.get_horizontal_layout(alignment)

segment1 = file.createIfcAlignmentHorizontalSegment(
    StartPoint=file.createIfcCartesianPoint(Coordinates=((500.,2500.))),
    StartDirection=math.radians(327.0613),
    StartRadiusOfCurvature=0.0,
    EndRadiusOfCurvature=0.0,
    SegmentLength=1956.785654,
    PredefinedType = "LINE"
)

end = ifcopenshell.api.alignment.append_segment(file,layout,segment1)

unit_scale = ifcopenshell.util.unit.calculate_unit_scale(file)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
dir = math.atan2(dy,dx)
segment2 = file.createIfcAlignmentHorizontalSegment(
    StartPoint=file.createIfcCartesianPoint((x,y)),
    StartDirection=dir,
    StartRadiusOfCurvature=1000.,
    EndRadiusOfCurvature=1000.,
    SegmentLength=1919.222667,
    PredefinedType="CIRCULARARC"
)
end = ifcopenshell.api.alignment.append_segment(file,layout,segment2)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
dir = math.atan2(dy,dx)
segment3 = file.createIfcAlignmentHorizontalSegment(
    StartPoint=file.createIfcCartesianPoint((x,y)),
    StartDirection=dir,
    StartRadiusOfCurvature=0.0,
    EndRadiusOfCurvature=0.0,
    SegmentLength=1886.905454,
    PredefinedType = "LINE"
)
end = ifcopenshell.api.alignment.append_segment(file,layout,segment3)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
dir = math.atan2(dy,dx)
segment4 = file.createIfcAlignmentHorizontalSegment(
    StartPoint=file.createIfcCartesianPoint((x,y)),
    StartDirection=dir,
    StartRadiusOfCurvature=-1250.,
    EndRadiusOfCurvature=-1250.,
    SegmentLength=1848.115835,
    PredefinedType="CIRCULARARC"
)
end = ifcopenshell.api.alignment.append_segment(file,layout,segment4)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
dir = math.atan2(dy,dx)
segment5 = file.createIfcAlignmentHorizontalSegment(
    StartPoint=file.createIfcCartesianPoint((x,y)),
    StartDirection=dir,
    StartRadiusOfCurvature=0.0,
    EndRadiusOfCurvature=0.0,
    SegmentLength=1564.635765,
    PredefinedType = "LINE"
)
end = ifcopenshell.api.alignment.append_segment(file,layout,segment5)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
dir = math.atan2(dy,dx)
segment6 = file.createIfcAlignmentHorizontalSegment(
    StartPoint=file.createIfcCartesianPoint((x,y)),
    StartDirection=dir,
    StartRadiusOfCurvature=-950.,
    EndRadiusOfCurvature=-950.,
    SegmentLength=1049.119737,
    PredefinedType="CIRCULARARC"
)
end = ifcopenshell.api.alignment.append_segment(file,layout,segment6)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
dir = math.atan2(dy,dx)
segment7 = file.createIfcAlignmentHorizontalSegment(
    StartPoint=file.createIfcCartesianPoint((x,y)),
    StartDirection=dir,
    StartRadiusOfCurvature=0.0,
    EndRadiusOfCurvature=0.0,
    SegmentLength=2112.285084,
    PredefinedType = "LINE"
)
end = ifcopenshell.api.alignment.append_segment(file,layout,segment7)

#ifcopenshell.api.alignment.util.print_alignment_deep(layout)

#curve = ifcopenshell.api.alignment.get_curve(alignment)

#ifcopenshell.api.alignment.util.print_composite_curve_deep(curve)



vlayout = ifcopenshell.api.alignment.get_vertical_layout(alignment)

segment1 = file.createIfcAlignmentVerticalSegment(
    StartDistAlong=0.,
    HorizontalLength=1200.,
    StartHeight=100.,
    StartGradient=1.75/100.,
    EndGradient=1.75/100.,
    PredefinedType = "CONSTANTGRADIENT"
)

end = ifcopenshell.api.alignment.append_segment(file,vlayout,segment1)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
segment2 = file.createIfcAlignmentVerticalSegment(
    StartDistAlong=x,
    HorizontalLength=1600.,
    StartHeight=y,
    StartGradient=dy/dx,
    EndGradient=-1./100.,
    PredefinedType = "PARABOLICARC"
)
end = ifcopenshell.api.alignment.append_segment(file,vlayout,segment2)


x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
segment3 = file.createIfcAlignmentVerticalSegment(
    StartDistAlong=x,
    HorizontalLength=1600.,
    StartHeight=y,
    StartGradient=dy/dx,
    EndGradient=-1./100.,
    PredefinedType = "CONSTANTGRADIENT"
)
end = ifcopenshell.api.alignment.append_segment(file,vlayout,segment3)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
segment4 = file.createIfcAlignmentVerticalSegment(
    StartDistAlong=x,
    HorizontalLength=1200.,
    StartHeight=y,
    StartGradient=dy/dx,
    EndGradient=2./100.,
    PredefinedType = "PARABOLICARC"
)
end = ifcopenshell.api.alignment.append_segment(file,vlayout,segment4)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
segment5 = file.createIfcAlignmentVerticalSegment(
    StartDistAlong=x,
    HorizontalLength=800.,
    StartHeight=y,
    StartGradient=dy/dx,
    EndGradient=2./100.,
    PredefinedType = "CONSTANTGRADIENT"
)
end = ifcopenshell.api.alignment.append_segment(file,vlayout,segment5)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
segment6 = file.createIfcAlignmentVerticalSegment(
    StartDistAlong=x,
    HorizontalLength=2000.,
    StartHeight=y,
    StartGradient=dy/dx,
    EndGradient=-2./100.,
    PredefinedType = "PARABOLICARC"
)
end = ifcopenshell.api.alignment.append_segment(file,vlayout,segment6)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
segment7 = file.createIfcAlignmentVerticalSegment(
    StartDistAlong=x,
    HorizontalLength=1000.,
    StartHeight=y,
    StartGradient=dy/dx,
    EndGradient=-2./100.,
    PredefinedType = "CONSTANTGRADIENT"
)
end = ifcopenshell.api.alignment.append_segment(file,vlayout,segment7)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
segment8 = file.createIfcAlignmentVerticalSegment(
    StartDistAlong=x,
    HorizontalLength=800.,
    StartHeight=y,
    StartGradient=dy/dx,
    EndGradient=-0.5/100.,
    PredefinedType = "PARABOLICARC"
)
end = ifcopenshell.api.alignment.append_segment(file,vlayout,segment8)

x = float(end[0,3])/unit_scale
y = float(end[1,3])/unit_scale
dx = float(end[0,0])
dy = float(end[1,0])
segment9 = file.createIfcAlignmentVerticalSegment(
    StartDistAlong=x,
    HorizontalLength=2600.,
    StartHeight=y,
    StartGradient=dy/dx,
    EndGradient=-0.5/100.,
    PredefinedType = "CONSTANTGRADIENT"
)
end = ifcopenshell.api.alignment.append_segment(file,vlayout,segment9)

ifcopenshell.api.alignment.util.print_alignment_deep(alignment)

curve = ifcopenshell.api.alignment.get_curve(alignment)

ifcopenshell.api.alignment.util.print_composite_curve_deep(curve)

referents = file.by_type("IfcReferent")
for referent in referents:
    print(referent)

settings = ifcopenshell.geom.settings()
shape = ifcopenshell.geom.create_shape(settings,curve)
verts = shape.verts
verts = np.array(verts).reshape((-1,3))
x,y,z = verts.T

x = [value/unit_scale for value in x]
y = [value/unit_scale for value in y]
z = [value/unit_scale for value in z]

gradient_curve = ifcopenshell.ifcopenshell_wrapper.map_shape(settings,curve.wrapped_data)
evaluator = ifcopenshell.ifcopenshell_wrapper.function_item_evaluator(settings,gradient_curve)
distances = evaluator.evaluation_points()

distances = [value/unit_scale for value in distances]

# horizontal plot
plt.plot(x,y)
plt.axis('equal')

# vertical plot
#plt.plot(distances,z)

plt.grid(True)
plt.show()
# Out:
#  #13=IfcAlignment('3tLMDnrX99avqFXmi4wU3u',$,'E-Line',$,$,#89,#22,$)
#    #80=IfcReferent('1KDdAL4O9BNAr5gpdjhaVl',$,'100+00.00',$,$,#79,$,.STATION.)
#    #14=IfcAlignmentHorizontal('1b6s6t$vP7wfrm9br7au_D',$,$,$,$,$,$)
#      #92=IfcAlignmentSegment('1AuIRq1KT8fwCv7jkM6p14',$,$,$,$,$,$,#91)
#        #107=IfcReferent('0epE7Cf457bOkt7Ct0PGEH',$,'P.O.B. (100+00.00)',$,$,#106,$,.POSITION.)
#        #91=IfcAlignmentHorizontalSegment($,$,#90,5.70829654085293,0.,0.,1956.785654,$,.LINE.)
#      #114=IfcAlignmentSegment('0fcU_qeRT3eBCAWqF8aHcb',$,$,$,$,$,$,#113)
#        #129=IfcReferent('2PsIcMkgD1Xu2v2E6o_L2p',$,'P.C. (119+56.79)',$,$,#128,$,.POSITION.)
#        #113=IfcAlignmentHorizontalSegment($,$,#112,-0.574888766326656,1000.,1000.,1919.222667,$,.CIRCULARARC.)
#      #136=IfcAlignmentSegment('3LJZaBhtLEhwcZ__$ZErHA',$,$,$,$,$,$,#135)
#        #151=IfcReferent('31I3ovP591RRxHatvuCiAa',$,'P.T. (138+76.01)',$,$,#150,$,.POSITION.)
#        #135=IfcAlignmentHorizontalSegment($,$,#134,1.34433390067334,0.,0.,1886.905454,$,.LINE.)
#      #158=IfcAlignmentSegment('02SS24NWzDYfQfIEMQN_7u',$,$,$,$,$,$,#157)
#        #173=IfcReferent('3TQIP5Z5vDLQMKr0piElux',$,'P.C. (157+62.91)',$,$,#172,$,.POSITION.)
#        #157=IfcAlignmentHorizontalSegment($,$,#156,1.34433390067334,-1250.,-1250.,1848.115835,$,.CIRCULARARC.)
#      #180=IfcAlignmentSegment('2MGZDFprL75gPN4GK6d2bt',$,$,$,$,$,$,#179)
#        #195=IfcReferent('1sus0DJmL6ovpntA6zUAFz',$,'P.T. (176+11.03)',$,$,#194,$,.POSITION.)
#        #179=IfcAlignmentHorizontalSegment($,$,#178,-0.134158767326656,0.,0.,1564.635765,$,.LINE.)
#      #202=IfcAlignmentSegment('1$TZ9b5Qv9bR0oe$QYzpKt',$,$,$,$,$,$,#201)
#        #217=IfcReferent('3xgwa$j2X1GBbZqYwMDiaJ',$,'P.C. (191+75.67)',$,$,#216,$,.POSITION.)
#        #201=IfcAlignmentHorizontalSegment($,$,#200,-0.134158767326656,-950.,-950.,1049.119737,$,.CIRCULARARC.)
#      #224=IfcAlignmentSegment('3mYXkZGNT0Fe7FzpyYJM4P',$,$,$,$,$,$,#223)
#        #239=IfcReferent('1PgRlt9HXCsRul4lOIiTrz',$,'P.T. (202+24.79)',$,$,#238,$,.POSITION.)
#        #223=IfcAlignmentHorizontalSegment($,$,#222,-1.23849533258981,0.,0.,2112.285084,$,.LINE.)
#      #27=IfcAlignmentSegment('2B0vO_$Dj1rfn72hl7k4EU',$,$,$,$,$,$,#26)
#        #52=IfcReferent('02OWxShgz1L9oPXCKnuvj0',$,'P.O.E. (202+24.79)',$,$,#51,$,.POSITION.)
#        #26=IfcAlignmentHorizontalSegment($,$,#25,0.,0.,0.,0.,$,.LINE.)
#    #15=IfcAlignmentVertical('2TDjQpP_r57xCkl7eFQ7xV',$,$,$,$,$,$)
#      #245=IfcAlignmentSegment('2hL_205srBk8vLoYd4EQR6',$,$,$,$,$,$,#244)
#        #261=IfcReferent('3o1TxDNMnA98NQvfertFq9',$,'V.P.O.B. (100+00.00)',$,$,#260,$,.POSITION.)
#        #244=IfcAlignmentVerticalSegment($,$,0.,1200.,100.,0.0175,0.0175,$,.CONSTANTGRADIENT.)
#      #267=IfcAlignmentSegment('2iizGmD2P5oP8tb0upgbLr',$,$,$,$,$,$,#266)
#        #283=IfcReferent('3dPkhcgtz3DgF71rwQsJe1',$,'B.V.C. (112+00.00)',$,$,#282,$,.POSITION.)
#        #266=IfcAlignmentVerticalSegment($,$,1200.,1600.,121.,0.0175,-0.01,$,.PARABOLICARC.)
#      #289=IfcAlignmentSegment('3NypjP4az91PVpP4P4m5Bd',$,$,$,$,$,$,#288)
#        #305=IfcReferent('04ROyn1_D45uQdFhoVdYd4',$,'E.V.C. (128+00.00)',$,$,#304,$,.POSITION.)
#        #288=IfcAlignmentVerticalSegment($,$,2799.99999384661,1600.,127.000000061534,-0.00999999989423861,-0.01,$,.CONSTANTGRADIENT.)
#      #311=IfcAlignmentSegment('2z4SXWsR9B9OigK2qzp1N9',$,$,$,$,$,$,#310)
#        #327=IfcReferent('0AXKaQziD7TQznAJx1eg8w',$,'B.V.C. (144+00.00)',$,$,#326,$,.POSITION.)
#        #310=IfcAlignmentVerticalSegment($,$,4399.99999384661,1200.,111.000000230752,-0.00999999989423861,0.02,$,.PARABOLICARC.)
#      #333=IfcAlignmentSegment('2db9DdgC18yBXw6EyvZTDU',$,$,$,$,$,$,#332)
#        #349=IfcReferent('1lKsJJ2DP6VOUsEIA8sfW5',$,'E.V.C. (156+00.00)',$,$,#348,$,.POSITION.)
#        #332=IfcAlignmentVerticalSegment($,$,5599.99998835535,800.,117.000000184384,0.0199999998627184,0.02,$,.CONSTANTGRADIENT.)
#      #355=IfcAlignmentSegment('2XPwJpciLBVulABRa1VScR',$,$,$,$,$,$,#354)
#        #371=IfcReferent('0sav9uvrH1eh6Yx2CTkZ$g',$,'B.V.C. (164+00.00)',$,$,#370,$,.POSITION.)
#        #354=IfcAlignmentVerticalSegment($,$,6399.99998835534,2000.,133.000000074558,0.0199999998627184,-0.02,$,.PARABOLICARC.)
#      #377=IfcAlignmentSegment('3bH7k7krTApv6Euc7Vuzry',$,$,$,$,$,$,#376)
#        #393=IfcReferent('2vrOgxnZPEePO$YTr$diTf',$,'E.V.C. (184+00.00)',$,$,#392,$,.POSITION.)
#        #376=IfcAlignmentVerticalSegment($,$,8399.99998428796,1000.,133.000000018624,-0.0199999999186523,-0.02,$,.CONSTANTGRADIENT.)
#      #399=IfcAlignmentSegment('2_ptVpBjb9LRH5mw7MVSg5',$,$,$,$,$,$,#398)
#        #415=IfcReferent('0t9Ul5AU53s8ZbfNPiqKKy',$,'B.V.C. (194+00.00)',$,$,#414,$,.POSITION.)
#        #398=IfcAlignmentVerticalSegment($,$,9399.99998428796,800.,113.000000099972,-0.0199999999186523,-0.005,$,.PARABOLICARC.)
#      #421=IfcAlignmentSegment('2Xv094nNjCoPp9MbaHh$fF',$,$,$,$,$,$,#420)
#        #437=IfcReferent('1qMrugMAP7YhEf98AmfQP3',$,'E.V.C. (202+00.00)',$,$,#436,$,.POSITION.)
#        #420=IfcAlignmentVerticalSegment($,$,10199.9999806269,2600.,103.000000150816,-0.00500000006864433,-0.005,$,.CONSTANTGRADIENT.)
#      #59=IfcAlignmentSegment('3sg9gKWqv1lu_qZik1k06A',$,$,$,$,$,$,#58)
#        #68=IfcReferent('1nI4vn83b7PejLHE9y_0v7',$,'V.P.O.E. (202+00.00)',$,$,#67,$,.POSITION.)
#        #58=IfcAlignmentVerticalSegment($,$,12799.9999806269,0.,89.9999999723411,-0.00500000006864433,-0.00500000006864433,$,.CONSTANTGRADIENT.)
# #23=IfcGradientCurve((#253,#275,#297,#319,#341,#363,#385,#407,#429,#36),.F.,#20,$)
#    #253=IfcCurveSegment(.CONTSAMEGRADIENT.,#252,IfcLengthMeasure(0.),IfcLengthMeasure(1200.18373593379),#249)
#      #249=IfcLine(#246,#248)
#      #252=IfcAxis2Placement2D(#250,#251)
#      #250=IfcCartesianPoint((0.,100.))
#      #251=IfcDirection((0.999846910161925,0.0174973209278337))
#    #275=IfcCurveSegment(.CONTSAMEGRADIENT.,#274,IfcLengthMeasure(0.),IfcLengthMeasure(1600.06166413409),#271)
#      #271=IfcPolynomialCurve(#270,(0.,1.),(121.,0.0175,-8.59375E-06),$)
#      #274=IfcAxis2Placement2D(#272,#273)
#      #272=IfcCartesianPoint((1200.,121.))
#      #273=IfcDirection((0.999846910161925,0.0174973209278337))
#    #297=IfcCurveSegment(.CONTSAMEGRADIENT.,#296,IfcLengthMeasure(0.),IfcLengthMeasure(1600.07999799841),#293)
#      #293=IfcLine(#290,#292)
#      #296=IfcAxis2Placement2D(#294,#295)
#      #294=IfcCartesianPoint((2799.99999384661,127.000000061534))
#      #295=IfcDirection((0.999950003750745,-0.00999949993175135))
#    #319=IfcCurveSegment(.CONTSAMEGRADIENT.,#318,IfcLengthMeasure(0.),IfcLengthMeasure(1200.05999670044),#315)
#      #315=IfcPolynomialCurve(#314,(0.,1.),(111.000000230752,-0.00999999989423861,1.24999999559328E-05),$)
#      #318=IfcAxis2Placement2D(#316,#317)
#      #316=IfcCartesianPoint((4399.99999384661,111.000000230752))
#      #317=IfcDirection((0.999950003750745,-0.00999949993175135))
#    #341=IfcCurveSegment(.CONTSAMEGRADIENT.,#340,IfcLengthMeasure(0.),IfcLengthMeasure(800.159984001003),#337)
#      #337=IfcLine(#334,#336)
#      #340=IfcAxis2Placement2D(#338,#339)
#      #338=IfcCartesianPoint((5599.99998835535,117.000000184384))
#      #339=IfcDirection((0.999800059982751,0.0199960010624009))
#    #363=IfcCurveSegment(.CONTSAMEGRADIENT.,#362,IfcLengthMeasure(0.),IfcLengthMeasure(2000.13332533356),#359)
#      #359=IfcPolynomialCurve(#358,(0.,1.),(133.000000074558,0.0199999998627184,-9.9999999656796E-06),$)
#      #362=IfcAxis2Placement2D(#360,#361)
#      #360=IfcCartesianPoint((6399.99998835534,133.000000074558))
#      #361=IfcDirection((0.999800059982751,0.0199960010624009))
#    #385=IfcCurveSegment(.CONTSAMEGRADIENT.,#384,IfcLengthMeasure(0.),IfcLengthMeasure(1000.19998000237),#381)
#      #381=IfcLine(#378,#380)
#      #384=IfcAxis2Placement2D(#382,#383)
#      #382=IfcCartesianPoint((8399.99998428796,133.000000018624))
#      #383=IfcDirection((0.999800059981633,-0.0199960011183013))
#    #407=IfcCurveSegment(.CONTSAMEGRADIENT.,#406,IfcLengthMeasure(0.),IfcLengthMeasure(800.069995737693),#403)
#      #403=IfcPolynomialCurve(#402,(0.,1.),(113.000000099972,-0.0199999999186523,9.37499994915771E-06),$)
#      #406=IfcAxis2Placement2D(#404,#405)
#      #404=IfcCartesianPoint((9399.99998428796,113.000000099972))
#      #405=IfcDirection((0.999800059981633,-0.0199960011183013))
#    #429=IfcCurveSegment(.CONTSAMEGRADIENTSAMECURVATURE.,#428,IfcLengthMeasure(0.),IfcLengthMeasure(2600.03249979777),#425)
#      #425=IfcLine(#422,#424)
#      #428=IfcAxis2Placement2D(#426,#427)
#      #426=IfcCartesianPoint((10199.9999806269,103.000000150816))
#      #427=IfcDirection((0.999987500234027,-0.00499993756981361))
#    #36=IfcCurveSegment(.DISCONTINUOUS.,#35,IfcLengthMeasure(0.),IfcLengthMeasure(0.),#32)
#      #32=IfcLine(#29,#31)
#      #35=IfcAxis2Placement2D(#33,#34)
#      #33=IfcCartesianPoint((12799.9999806269,89.9999999723411))
#      #34=IfcDirection((0.999987500234027,-0.00499993756981361))
# #52=IfcReferent('02OWxShgz1L9oPXCKnuvj0',$,'P.O.E. (202+24.79)',$,$,#51,$,.POSITION.)
# #68=IfcReferent('1nI4vn83b7PejLHE9y_0v7',$,'V.P.O.E. (202+00.00)',$,$,#67,$,.POSITION.)
# #80=IfcReferent('1KDdAL4O9BNAr5gpdjhaVl',$,'100+00.00',$,$,#79,$,.STATION.)
# #107=IfcReferent('0epE7Cf457bOkt7Ct0PGEH',$,'P.O.B. (100+00.00)',$,$,#106,$,.POSITION.)
# #129=IfcReferent('2PsIcMkgD1Xu2v2E6o_L2p',$,'P.C. (119+56.79)',$,$,#128,$,.POSITION.)
# #151=IfcReferent('31I3ovP591RRxHatvuCiAa',$,'P.T. (138+76.01)',$,$,#150,$,.POSITION.)
# #173=IfcReferent('3TQIP5Z5vDLQMKr0piElux',$,'P.C. (157+62.91)',$,$,#172,$,.POSITION.)
# #195=IfcReferent('1sus0DJmL6ovpntA6zUAFz',$,'P.T. (176+11.03)',$,$,#194,$,.POSITION.)
# #217=IfcReferent('3xgwa$j2X1GBbZqYwMDiaJ',$,'P.C. (191+75.67)',$,$,#216,$,.POSITION.)
# #239=IfcReferent('1PgRlt9HXCsRul4lOIiTrz',$,'P.T. (202+24.79)',$,$,#238,$,.POSITION.)
# #261=IfcReferent('3o1TxDNMnA98NQvfertFq9',$,'V.P.O.B. (100+00.00)',$,$,#260,$,.POSITION.)
# #283=IfcReferent('3dPkhcgtz3DgF71rwQsJe1',$,'B.V.C. (112+00.00)',$,$,#282,$,.POSITION.)
# #305=IfcReferent('04ROyn1_D45uQdFhoVdYd4',$,'E.V.C. (128+00.00)',$,$,#304,$,.POSITION.)
# #327=IfcReferent('0AXKaQziD7TQznAJx1eg8w',$,'B.V.C. (144+00.00)',$,$,#326,$,.POSITION.)
# #349=IfcReferent('1lKsJJ2DP6VOUsEIA8sfW5',$,'E.V.C. (156+00.00)',$,$,#348,$,.POSITION.)
# #371=IfcReferent('0sav9uvrH1eh6Yx2CTkZ$g',$,'B.V.C. (164+00.00)',$,$,#370,$,.POSITION.)
# #393=IfcReferent('2vrOgxnZPEePO$YTr$diTf',$,'E.V.C. (184+00.00)',$,$,#392,$,.POSITION.)
# #415=IfcReferent('0t9Ul5AU53s8ZbfNPiqKKy',$,'B.V.C. (194+00.00)',$,$,#414,$,.POSITION.)
# #437=IfcReferent('1qMrugMAP7YhEf98AmfQP3',$,'E.V.C. (202+00.00)',$,$,#436,$,.POSITION.)
